# %%
# # Import the Twython class
from twython import Twython
# import csv
import json

# # Instantiate an object
python_tweets = Twython('OuU4ihzPX8aOFtt9gvb7envzM','yYicuj0suUFJNUfRoSxubEDguVoBzVyVw6RXsqJOV2HQ9tbzNd')

topic = 'ADHD OR #ADHD OR Attention deficit hyperactivity disorder OR Attention-deficit/hyperactivity disorder -RT'
# Create our query
query = {'q': topic,'count':1000, 'since':'2019-01-01', 'location':'USA', 'language':'en'}

# # data = {}
# # for status in python_tweets.search(**query)['statuses']:
# #     print(status['text'])
# #     with open('ADHD11Apr.json', 'a+') as f:
# #         json.dump(status,f)
# #         f.write("\n")

# # csvFile = open('ADHD13Apr.csv', 'a', encoding="utf-8")
# # csvWriter = csv.writer(csvFile)
with open('DIC-Lab2/txt/ADHD20Apr.txt', 'a+', encoding="utf-8") as f:
    with open('DIC-Lab2/json/ADHD20Apr.json', 'a+') as f1:
        for status in python_tweets.search(**query)['statuses']:
            text = status['text']
            text = text.replace('\n',' ')
            f.write(text)
            f.write("\n")
            json.dump(status,f1)
            f1.write("\n")
            print(status['text'])
    f1.close()
f.close()

topic = 'PTSD OR #PTSD OR Post traumatic stress disorder -RT'
# Create our query
query = {'q': topic,'count':1000, 'since':'2019-01-01', 'location':'USA', 'language':'en'}
with open('DIC-Lab2/txt/PTSD20Apr.txt', 'a+', encoding="utf-8") as f:
    with open('DIC-Lab2/json/PTSD20Apr.json', 'a+') as f1:
        for status in python_tweets.search(**query)['statuses']:
            text = status['text']
            text = text.replace('\n',' ')
            f.write(text)
            f.write("\n")
            json.dump(status,f1)
            f1.write("\n")
            print(status['text'])
    f1.close()
f.close()

topic = 'Anxiety OR Anxiety disorder OR anxiety disorder -RT'
# Create our query
query = {'q': topic,'count':1000, 'since':'2019-01-01', 'location':'USA', 'language':'en'}
with open('DIC-Lab2/txt/AD20Apr.txt', 'a+', encoding="utf-8") as f:
    with open('DIC-Lab2/json/AD20Apr.json', 'a+') as f1:
        for status in python_tweets.search(**query)['statuses']:
            text = status['text']
            text = text.replace('\n',' ')
            f.write(text)
            f.write("\n")
            json.dump(status,f1)
            f1.write("\n")
            print(status['text'])
    f1.close()
f.close()

topic = 'Eating disorder OR eating disorder OR bulimia -RT'
# Create our query
query = {'q': topic,'count':1000, 'since':'2019-01-01', 'location':'USA', 'language':'en'}
with open('DIC-Lab2/txt/ED20Apr.txt', 'a+', encoding="utf-8") as f:
    with open('DIC-Lab2/json/ED20Apr.json', 'a+') as f1:
        for status in python_tweets.search(**query)['statuses']:
            text = status['text']
            text = text.replace('\n',' ')
            f.write(text)
            f.write("\n")
            json.dump(status,f1)
            f1.write("\n")
            print(status['text'])
    f1.close()
f.close()

topic = 'Depression OR clinical depression OR depressed -RT'
# Create our query
query = {'q': topic,'count':1000, 'since':'2019-01-01', 'location':'USA', 'language':'en'}
with open('DIC-Lab2/txt/CD20Apr.txt', 'a+', encoding="utf-8") as f:
    with open('DIC-Lab2/json/CD20Apr.json', 'a+') as f1:
        for status in python_tweets.search(**query)['statuses']:
            text = status['text']
            text = text.replace('\n',' ')
            f.write(text)
            f.write("\n")
            json.dump(status,f1)
            f1.write("\n")
            print(status['text'])
    f1.close()
f.close()

topic = 'Bipolar Disorder OR bipolar disorder OR bipolar -RT'
# Create our query
query = {'q': topic,'count':1000, 'since':'2019-01-01', 'location':'USA', 'language':'en'}
with open('DIC-Lab2/jsonBD20Apr.txt', 'a+', encoding="utf-8") as f:
    with open('DIC-Lab2/json/BD20Apr.json', 'a+') as f1:
        for status in python_tweets.search(**query)['statuses']:
            text = status['text']
            text = text.replace('\n',' ')
            f.write(text)
            f.write("\n")
            json.dump(status,f1)
            f1.write("\n")
            print(status['text'])
    f1.close()
f.close()
# Out:
# ADHD(Attention-Deficit/Hyperactivity Disorder)
# 日本語で「注意欠如・多動症（注意欠陥/ 多動性障害、注意欠如・多動性障害）」と言う。
# 自分をコントロールする力が弱く、それが行動面の問題となってあらわれる障害です。
# ADHDとは（小児・思春期）
#
# ADHD（Attention-deficit / hyperactivity disorder：注意欠如・多動性障害）とは、年齢や発達に不つりあいな不注意さや多動性、衝動性を特徴とする発達障害*で、日常活動や学習に支障をきたす状態をいいます。
# As increasing number of women continue to be diagnosed with Attention Deficit Hyperactivity Disorder later on in li… https://t.co/Zgr3bBE4LL
# Are you a parent or caregiver raising an 8-12 year old child with attention deficit hyperactivity disorder #ADHD?… https://t.co/O9LzSAoCsC
# ADHD - Attention Deficit Hyperactivity Disorder my A$$. In Nigeria its #restless and needs a good flogging syndrome lol
# Assessing causality in the association between attention-deficit/hyperactivity disorder and obesity: a Mendelian ra… https://t.co/tVJP1GC3wX
# The first medical device to treat childhood attention deficit hyperactivity disorder, or ADHD, was OK'd Friday by t… https://t.co/8CYOhRsmZT
# ...
